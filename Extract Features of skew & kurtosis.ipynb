# %% [markdown]
# # Project - Deep Learning Based Leak Detection System for Oil pipelines
#
# This code is to extract features of skew and kurtosis from input samples as the input of the Full Connected Neural Networks.
#
# The input samples are nonstationary and nonlinear time series pressure signals. Each sample was decomposed into a sum of finite stationary intrinsic mode functions (IMF) by using EMD (Empirical Mode Decomposition) method.
#
# The features of " skewness” and "kurtosis" are extracted from each IMF as the input of the Full Connected Neural Networks.
#
# Team 17.
#
# Team member: Haixia Wu

# %%
import numpy as np
import pandas as pd
from pyhht import EMD
from scipy import stats

# %%
max_imf = 15 #maximun number of imfs

skew_d = 'skew_d_'
kur_d = 'kur_d_'
skew_s = 'skew_s_'
kur_s = 'kur_s_'

# %%
dataset_filename = "./dataset_resized/dataset_resized_leak_artificial.csv"
df = pd.read_csv(dataset_filename)
df = df[['file_path', 'date', 'time', 'label', 'segment']]
df
# Out:
#                                          file_path        date      time  \
# 0        ./dataset_resized/leak/small_artificial/1  2021.01.01  00:00:00
# 1        ./dataset_resized/leak/small_artificial/2  2021.01.01  00:00:00
# 2        ./dataset_resized/leak/small_artificial/3  2021.01.01  00:00:00
# 3        ./dataset_resized/leak/small_artificial/4  2021.01.01  00:00:00
# 4        ./dataset_resized/leak/small_artificial/5  2021.01.01  00:00:00
# ...                                            ...         ...       ...
# 2239  ./dataset_resized/leak/small_artificial/2240  2021.01.01  00:00:00
# 2240  ./dataset_resized/leak/small_artificial/2241  2021.01.01  00:00:00
# 2241  ./dataset_resized/leak/small_artificial/2242  2021.01.01  00:00:00
# 2242  ./dataset_resized/leak/small_artificial/2243  2021.01.01  00:00:00
# 2243  ./dataset_resized/leak/small_artificial/2244  2021.01.01  00:00:00
#
#      label  segment
# 0     leak  1VA_3VA
# 1     leak  1VA_3VA
# 2     leak  1VA_3VA
# 3     leak  1VA_3VA
# 4     leak  1VA_3VA
# ...    ...      ...
# 2239  leak  1VA_3VA
# 2240  leak  1VA_3VA
# 2241  leak  1VA_3VA
# 2242  leak  1VA_3VA
# 2243  leak  1VA_3VA
#
# [2244 rows x 5 columns]

# %%
skew_d = 'skew_d_'
kur_d = 'kur_d_'
skew_s = 'skew_s_'
kur_s = 'kur_s_'

for i in range(0, max_imf):
    df[skew_d + str(i)] = ''
    df[kur_d + str(i)] = '' 
    df[skew_s + str(i)] = ''
    df[kur_s + str(i)] = '' 
    
for index, row in df.iterrows():
    file_name = row['file_path'] + '.csv'
    print(file_name)
    dataframe_sample = pd.read_csv(file_name)
    
    #discharge pressure
    decomposer = EMD(dataframe_sample['discharge_pressure'])
    imfs = decomposer.decompose()

    for n, imf in enumerate(imfs):
        if n <= max_imf:
            row[skew_d + str(n)] = stats.skew(imf) #calculate skewness
            row[kur_d + str(n)] = stats.kurtosis(imf) #calculate kurtosis  
        else:
            n = max_imf
        
    for i in range(n+1, max_imf):
        row[skew_d + str(i)] = 0
        row[kur_d + str(i)] = 0     
             
    #suction pressure
    decomposer = EMD(dataframe_sample['suction_pressure'])
    imfs = decomposer.decompose()

    for n, imf in enumerate(imfs):
        if n <= max_imf:
            row[skew_s + str(n)] = stats.skew(imf) #calculate skewness
            row[kur_s + str(n)] = stats.kurtosis(imf) #calculate kurtosis   
        else:
            n = max_imf
            
    for i in range(n+1, max_imf):
        row[skew_s + str(i)] = 0
        row[kur_s + str(i)] = 0
# Out:
# ./dataset_resized/leak/small_artificial/1.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/2.csv
# ./dataset_resized/leak/small_artificial/3.csv
# Mode 10, Iteration 600
# 0 minima > 0; 2 maxima < 0.
# ./dataset_resized/leak/small_artificial/4.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 9, Iteration 600
# 1 minima > 0; 4 maxima < 0.
# Mode 9, Iteration 800
# 1 minima > 0; 4 maxima < 0.
# Mode 9, Iteration 1000
# 1 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/5.csv
# ./dataset_resized/leak/small_artificial/6.csv
# ./dataset_resized/leak/small_artificial/7.csv
# ./dataset_resized/leak/small_artificial/8.csv
# ./dataset_resized/leak/small_artificial/9.csv
# ./dataset_resized/leak/small_artificial/10.csv
# ./dataset_resized/leak/small_artificial/11.csv
# ./dataset_resized/leak/small_artificial/12.csv
# ./dataset_resized/leak/small_artificial/13.csv
# ./dataset_resized/leak/small_artificial/14.csv
# ./dataset_resized/leak/small_artificial/15.csv
# Mode 8, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/16.csv
# ./dataset_resized/leak/small_artificial/17.csv
# ./dataset_resized/leak/small_artificial/18.csv
# ./dataset_resized/leak/small_artificial/19.csv
# ./dataset_resized/leak/small_artificial/20.csv
# ./dataset_resized/leak/small_artificial/21.csv
# ./dataset_resized/leak/small_artificial/22.csv
# ./dataset_resized/leak/small_artificial/23.csv
# ./dataset_resized/leak/small_artificial/24.csv
# ./dataset_resized/leak/small_artificial/25.csv
# ./dataset_resized/leak/small_artificial/26.csv
# ./dataset_resized/leak/small_artificial/27.csv
# ./dataset_resized/leak/small_artificial/28.csv
# ./dataset_resized/leak/small_artificial/29.csv
# ./dataset_resized/leak/small_artificial/30.csv
# ./dataset_resized/leak/small_artificial/31.csv
# ./dataset_resized/leak/small_artificial/32.csv
# ./dataset_resized/leak/small_artificial/33.csv
# ./dataset_resized/leak/small_artificial/34.csv
# Mode 10, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 600
# 0 minima > 0; 11 maxima < 0.
# ./dataset_resized/leak/small_artificial/35.csv
# ./dataset_resized/leak/small_artificial/36.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/37.csv
# Mode 9, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/38.csv
# ./dataset_resized/leak/small_artificial/39.csv
# Mode 11, Iteration 600
# 0 minima > 0; 2 maxima < 0.
# ./dataset_resized/leak/small_artificial/40.csv
# ./dataset_resized/leak/small_artificial/41.csv
# ./dataset_resized/leak/small_artificial/42.csv
# ./dataset_resized/leak/small_artificial/43.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/44.csv
# ./dataset_resized/leak/small_artificial/45.csv
# ./dataset_resized/leak/small_artificial/46.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/47.csv
# ./dataset_resized/leak/small_artificial/48.csv
# ./dataset_resized/leak/small_artificial/49.csv
# ./dataset_resized/leak/small_artificial/50.csv
# ./dataset_resized/leak/small_artificial/51.csv
# ./dataset_resized/leak/small_artificial/52.csv
# ./dataset_resized/leak/small_artificial/53.csv
# ./dataset_resized/leak/small_artificial/54.csv
# Mode 8, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/55.csv
# Mode 8, Iteration 600
# 1 minima > 0; 11 maxima < 0.
# Mode 8, Iteration 800
# 1 minima > 0; 12 maxima < 0.
# Mode 8, Iteration 1000
# 1 minima > 0; 11 maxima < 0.
# Mode 9, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/56.csv
# Mode 6, Iteration 600
# 0 minima > 0; 19 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 11 maxima < 0.
# ./dataset_resized/leak/small_artificial/57.csv
# Mode 8, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/58.csv
# ./dataset_resized/leak/small_artificial/59.csv
# ./dataset_resized/leak/small_artificial/60.csv
# ./dataset_resized/leak/small_artificial/61.csv
# Mode 10, Iteration 600
# 1 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/62.csv
# ./dataset_resized/leak/small_artificial/63.csv
# ./dataset_resized/leak/small_artificial/64.csv
# ./dataset_resized/leak/small_artificial/65.csv
# ./dataset_resized/leak/small_artificial/66.csv
# ./dataset_resized/leak/small_artificial/67.csv
# ./dataset_resized/leak/small_artificial/68.csv
# ./dataset_resized/leak/small_artificial/69.csv
# ./dataset_resized/leak/small_artificial/70.csv
# ./dataset_resized/leak/small_artificial/71.csv
# ./dataset_resized/leak/small_artificial/72.csv
# ./dataset_resized/leak/small_artificial/73.csv
# ./dataset_resized/leak/small_artificial/74.csv
# ./dataset_resized/leak/small_artificial/75.csv
# Mode 9, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/76.csv
# ./dataset_resized/leak/small_artificial/77.csv
# ./dataset_resized/leak/small_artificial/78.csv
# ./dataset_resized/leak/small_artificial/79.csv
# ./dataset_resized/leak/small_artificial/80.csv
# ./dataset_resized/leak/small_artificial/81.csv
# ./dataset_resized/leak/small_artificial/82.csv
# ./dataset_resized/leak/small_artificial/83.csv
# ./dataset_resized/leak/small_artificial/84.csv
# Mode 7, Iteration 600
# 0 minima > 0; 22 maxima < 0.
# ./dataset_resized/leak/small_artificial/85.csv
# ./dataset_resized/leak/small_artificial/86.csv
# ./dataset_resized/leak/small_artificial/87.csv
# ./dataset_resized/leak/small_artificial/88.csv
# Mode 7, Iteration 600
# 1 minima > 0; 24 maxima < 0.
# ./dataset_resized/leak/small_artificial/89.csv
# ./dataset_resized/leak/small_artificial/90.csv
# ./dataset_resized/leak/small_artificial/91.csv
# Mode 8, Iteration 600
# 0 minima > 0; 11 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/92.csv
# ./dataset_resized/leak/small_artificial/93.csv
# Mode 7, Iteration 600
# 0 minima > 0; 14 maxima < 0.
# Mode 7, Iteration 800
# 1 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 1000
# 0 minima > 0; 16 maxima < 0.
# Mode 7, Iteration 1200
# 0 minima > 0; 16 maxima < 0.
# Mode 7, Iteration 1400
# 0 minima > 0; 16 maxima < 0.
# Mode 7, Iteration 1600
# 0 minima > 0; 16 maxima < 0.
# Mode 7, Iteration 1800
# 0 minima > 0; 16 maxima < 0.
# C:\Users\18612\anaconda3\envs\ensf-ml\lib\site-packages\pyhht\emd.py:367: UserWarning: Emd:warning, Forced stop of sifting - Maximum iteration limit reached.
#   warnings.warn("Emd:warning, Forced stop of sifting - " +
# ./dataset_resized/leak/small_artificial/94.csv
# ./dataset_resized/leak/small_artificial/95.csv
# ./dataset_resized/leak/small_artificial/96.csv
# ./dataset_resized/leak/small_artificial/97.csv
# ./dataset_resized/leak/small_artificial/98.csv
# ./dataset_resized/leak/small_artificial/99.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/100.csv
# ./dataset_resized/leak/small_artificial/101.csv
# Mode 8, Iteration 600
# 0 minima > 0; 14 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/102.csv
# ./dataset_resized/leak/small_artificial/103.csv
# Mode 7, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/104.csv
# ./dataset_resized/leak/small_artificial/105.csv
# ./dataset_resized/leak/small_artificial/106.csv
# Mode 11, Iteration 600
# 0 minima > 0; 2 maxima < 0.
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/107.csv
# ./dataset_resized/leak/small_artificial/108.csv
# ./dataset_resized/leak/small_artificial/109.csv
# ./dataset_resized/leak/small_artificial/110.csv
# Mode 6, Iteration 600
# 1 minima > 0; 51 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 36 maxima < 0.
# Mode 8, Iteration 1000
# 0 minima > 0; 24 maxima < 0.
# Mode 11, Iteration 1200
# 0 minima > 0; 3 maxima < 0.
# Mode 9, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# Mode 9, Iteration 800
# 1 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/111.csv
# ./dataset_resized/leak/small_artificial/112.csv
# ./dataset_resized/leak/small_artificial/113.csv
# Mode 9, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/114.csv
# ./dataset_resized/leak/small_artificial/115.csv
# ./dataset_resized/leak/small_artificial/116.csv
# ./dataset_resized/leak/small_artificial/117.csv
# ./dataset_resized/leak/small_artificial/118.csv
# ./dataset_resized/leak/small_artificial/119.csv
# Mode 7, Iteration 600
# 1 minima > 0; 19 maxima < 0.
# Mode 7, Iteration 800
# 1 minima > 0; 19 maxima < 0.
# Mode 9, Iteration 1000
# 1 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/120.csv
# ./dataset_resized/leak/small_artificial/121.csv
# ./dataset_resized/leak/small_artificial/122.csv
# ./dataset_resized/leak/small_artificial/123.csv
# ./dataset_resized/leak/small_artificial/124.csv
# ./dataset_resized/leak/small_artificial/125.csv
# ./dataset_resized/leak/small_artificial/126.csv
# ./dataset_resized/leak/small_artificial/127.csv
# Mode 9, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 6 maxima < 0.
# Mode 9, Iteration 1200
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/128.csv
# ./dataset_resized/leak/small_artificial/129.csv
# ./dataset_resized/leak/small_artificial/130.csv
# Mode 9, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 600
# 1 minima > 0; 9 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 10 maxima < 0.
# Mode 10, Iteration 1000
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/131.csv
# Mode 9, Iteration 600
# 1 minima > 0; 7 maxima < 0.
# Mode 10, Iteration 800
# 1 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/132.csv
# ./dataset_resized/leak/small_artificial/133.csv
# ./dataset_resized/leak/small_artificial/134.csv
# ./dataset_resized/leak/small_artificial/135.csv
# ./dataset_resized/leak/small_artificial/136.csv
# ./dataset_resized/leak/small_artificial/137.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 800
# 1 minima > 0; 7 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 1200
# 1 minima > 0; 6 maxima < 0.
# Mode 10, Iteration 1400
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/138.csv
# ./dataset_resized/leak/small_artificial/139.csv
# ./dataset_resized/leak/small_artificial/140.csv
# ./dataset_resized/leak/small_artificial/141.csv
# ./dataset_resized/leak/small_artificial/142.csv
# ./dataset_resized/leak/small_artificial/143.csv
# Mode 7, Iteration 600
# 0 minima > 0; 29 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/144.csv
# ./dataset_resized/leak/small_artificial/145.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/146.csv
# ./dataset_resized/leak/small_artificial/147.csv
# Mode 7, Iteration 600
# 0 minima > 0; 19 maxima < 0.
# ./dataset_resized/leak/small_artificial/148.csv
# Mode 9, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/149.csv
# ./dataset_resized/leak/small_artificial/150.csv
# Mode 7, Iteration 600
# 0 minima > 0; 17 maxima < 0.
# ./dataset_resized/leak/small_artificial/151.csv
# Mode 6, Iteration 600
# 0 minima > 0; 42 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/152.csv
# ./dataset_resized/leak/small_artificial/153.csv
# ./dataset_resized/leak/small_artificial/154.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/155.csv
# ./dataset_resized/leak/small_artificial/156.csv
# ./dataset_resized/leak/small_artificial/157.csv
# Mode 7, Iteration 600
# 0 minima > 0; 26 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 27 maxima < 0.
# Mode 7, Iteration 1000
# 0 minima > 0; 27 maxima < 0.
# Mode 7, Iteration 1200
# 0 minima > 0; 27 maxima < 0.
# Mode 8, Iteration 1400
# 0 minima > 0; 18 maxima < 0.
# ./dataset_resized/leak/small_artificial/158.csv
# Mode 9, Iteration 600
# 1 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/159.csv
# ./dataset_resized/leak/small_artificial/160.csv
# ./dataset_resized/leak/small_artificial/161.csv
# ./dataset_resized/leak/small_artificial/162.csv
# Mode 9, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/163.csv
# Mode 8, Iteration 600
# 1 minima > 0; 7 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/164.csv
# ./dataset_resized/leak/small_artificial/165.csv
# Mode 9, Iteration 600
# 1 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/166.csv
# Mode 8, Iteration 600
# 0 minima > 0; 16 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 16 maxima < 0.
# ./dataset_resized/leak/small_artificial/167.csv
# ./dataset_resized/leak/small_artificial/168.csv
# ./dataset_resized/leak/small_artificial/169.csv
# ./dataset_resized/leak/small_artificial/170.csv
# ./dataset_resized/leak/small_artificial/171.csv
# ./dataset_resized/leak/small_artificial/172.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 8 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/173.csv
# ./dataset_resized/leak/small_artificial/174.csv
# ./dataset_resized/leak/small_artificial/175.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/176.csv
# ./dataset_resized/leak/small_artificial/177.csv
# Mode 3, Iteration 600
# 0 minima > 0; 339 maxima < 0.
# Mode 2, Iteration 600
# 0 minima > 0; 389 maxima < 0.
# Mode 2, Iteration 800
# 0 minima > 0; 391 maxima < 0.
# Mode 2, Iteration 1000
# 0 minima > 0; 393 maxima < 0.
# Mode 6, Iteration 1200
# 0 minima > 0; 40 maxima < 0.
# ./dataset_resized/leak/small_artificial/178.csv
# Mode 7, Iteration 600
# 0 minima > 0; 19 maxima < 0.
# ./dataset_resized/leak/small_artificial/179.csv
# ./dataset_resized/leak/small_artificial/180.csv
# ./dataset_resized/leak/small_artificial/181.csv
# Mode 7, Iteration 600
# 0 minima > 0; 11 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 11 maxima < 0.
# Mode 7, Iteration 1000
# 0 minima > 0; 11 maxima < 0.
# Mode 7, Iteration 1200
# 0 minima > 0; 11 maxima < 0.
# Mode 7, Iteration 1400
# 0 minima > 0; 11 maxima < 0.
# Mode 8, Iteration 1600
# 0 minima > 0; 7 maxima < 0.
# Mode 9, Iteration 1800
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/182.csv
# ./dataset_resized/leak/small_artificial/183.csv
# ./dataset_resized/leak/small_artificial/184.csv
# Mode 8, Iteration 600
# 0 minima > 0; 10 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/185.csv
# Mode 9, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/186.csv
# ./dataset_resized/leak/small_artificial/187.csv
# Mode 9, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 3, Iteration 600
# 1 minima > 0; 198 maxima < 0.
# Mode 3, Iteration 800
# 1 minima > 0; 198 maxima < 0.
# Mode 3, Iteration 1000
# 0 minima > 0; 200 maxima < 0.
# Mode 4, Iteration 1200
# 2 minima > 0; 144 maxima < 0.
# ./dataset_resized/leak/small_artificial/188.csv
# Mode 8, Iteration 600
# 0 minima > 0; 15 maxima < 0.
# ./dataset_resized/leak/small_artificial/189.csv
# ./dataset_resized/leak/small_artificial/190.csv
# ./dataset_resized/leak/small_artificial/191.csv
# ./dataset_resized/leak/small_artificial/192.csv
# ./dataset_resized/leak/small_artificial/193.csv
# ./dataset_resized/leak/small_artificial/194.csv
# Mode 7, Iteration 600
# 0 minima > 0; 20 maxima < 0.
# Mode 8, Iteration 600
# 0 minima > 0; 12 maxima < 0.
# Mode 8, Iteration 800
# 1 minima > 0; 11 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/195.csv
# ./dataset_resized/leak/small_artificial/196.csv
# Mode 9, Iteration 600
# 1 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/197.csv
# ./dataset_resized/leak/small_artificial/198.csv
# Mode 6, Iteration 600
# 0 minima > 0; 41 maxima < 0.
# Mode 6, Iteration 800
# 0 minima > 0; 41 maxima < 0.
# Mode 8, Iteration 1000
# 0 minima > 0; 12 maxima < 0.
# Mode 8, Iteration 1200
# 0 minima > 0; 11 maxima < 0.
# ./dataset_resized/leak/small_artificial/199.csv
# ./dataset_resized/leak/small_artificial/200.csv
# Mode 8, Iteration 600
# 0 minima > 0; 19 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 19 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/201.csv
# ./dataset_resized/leak/small_artificial/202.csv
# Mode 8, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/203.csv
# ./dataset_resized/leak/small_artificial/204.csv
# ./dataset_resized/leak/small_artificial/205.csv
# Mode 8, Iteration 600
# 1 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/206.csv
# Mode 6, Iteration 600
# 0 minima > 0; 48 maxima < 0.
# ./dataset_resized/leak/small_artificial/207.csv
# ./dataset_resized/leak/small_artificial/208.csv
# Mode 9, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 800
# 1 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 1000
# 0 minima > 0; 2 maxima < 0.
# ./dataset_resized/leak/small_artificial/209.csv
# Mode 9, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/210.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/211.csv
# Mode 9, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/212.csv
# ./dataset_resized/leak/small_artificial/213.csv
# ./dataset_resized/leak/small_artificial/214.csv
# ./dataset_resized/leak/small_artificial/215.csv
# ./dataset_resized/leak/small_artificial/216.csv
# Mode 6, Iteration 600
# 0 minima > 0; 31 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/217.csv
# Mode 8, Iteration 600
# 1 minima > 0; 12 maxima < 0.
# ./dataset_resized/leak/small_artificial/218.csv
# Mode 8, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 6 maxima < 0.
# Mode 8, Iteration 1000
# 0 minima > 0; 6 maxima < 0.
# Mode 8, Iteration 1200
# 0 minima > 0; 6 maxima < 0.
# Mode 8, Iteration 1400
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/219.csv
# ./dataset_resized/leak/small_artificial/220.csv
# ./dataset_resized/leak/small_artificial/221.csv
# ./dataset_resized/leak/small_artificial/222.csv
# ./dataset_resized/leak/small_artificial/223.csv
# ./dataset_resized/leak/small_artificial/224.csv
# ./dataset_resized/leak/small_artificial/225.csv
# ./dataset_resized/leak/small_artificial/226.csv
# ./dataset_resized/leak/small_artificial/227.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/228.csv
# Mode 3, Iteration 600
# 0 minima > 0; 289 maxima < 0.
# Mode 3, Iteration 800
# 0 minima > 0; 289 maxima < 0.
# Mode 3, Iteration 1000
# 0 minima > 0; 289 maxima < 0.
# Mode 3, Iteration 1200
# 0 minima > 0; 289 maxima < 0.
# ./dataset_resized/leak/small_artificial/229.csv
# Mode 7, Iteration 600
# 0 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 1000
# 0 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 1200
# 0 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 1400
# 0 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 1600
# 0 minima > 0; 17 maxima < 0.
# ./dataset_resized/leak/small_artificial/230.csv
# ./dataset_resized/leak/small_artificial/231.csv
# ./dataset_resized/leak/small_artificial/232.csv
# Mode 6, Iteration 600
# 0 minima > 0; 38 maxima < 0.
# Mode 9, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/233.csv
# ./dataset_resized/leak/small_artificial/234.csv
# ./dataset_resized/leak/small_artificial/235.csv
# Mode 7, Iteration 600
# 0 minima > 0; 29 maxima < 0.
# ./dataset_resized/leak/small_artificial/236.csv
# Mode 7, Iteration 600
# 0 minima > 0; 18 maxima < 0.
# ./dataset_resized/leak/small_artificial/237.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/238.csv
# Mode 7, Iteration 600
# 0 minima > 0; 14 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 15 maxima < 0.
# Mode 7, Iteration 1000
# 0 minima > 0; 15 maxima < 0.
# Mode 7, Iteration 1200
# 0 minima > 0; 15 maxima < 0.
# Mode 8, Iteration 1400
# 1 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/239.csv
# Mode 4, Iteration 600
# 2 minima > 0; 99 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 20 maxima < 0.
# ./dataset_resized/leak/small_artificial/240.csv
# ./dataset_resized/leak/small_artificial/241.csv
# ./dataset_resized/leak/small_artificial/242.csv
# Mode 10, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/243.csv
# Mode 9, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 6, Iteration 600
# 0 minima > 0; 33 maxima < 0.
# Mode 8, Iteration 800
# 1 minima > 0; 11 maxima < 0.
# ./dataset_resized/leak/small_artificial/244.csv
# ./dataset_resized/leak/small_artificial/245.csv
# Mode 8, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/246.csv
# ./dataset_resized/leak/small_artificial/247.csv
# ./dataset_resized/leak/small_artificial/248.csv
# ./dataset_resized/leak/small_artificial/249.csv
# ./dataset_resized/leak/small_artificial/250.csv
# ./dataset_resized/leak/small_artificial/251.csv
# ./dataset_resized/leak/small_artificial/252.csv
# ./dataset_resized/leak/small_artificial/253.csv
# Mode 10, Iteration 600
# 0 minima > 0; 2 maxima < 0.
# Mode 8, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/254.csv
# ./dataset_resized/leak/small_artificial/255.csv
# ./dataset_resized/leak/small_artificial/256.csv
# ./dataset_resized/leak/small_artificial/257.csv
# Mode 8, Iteration 600
# 0 minima > 0; 17 maxima < 0.
# Mode 9, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/258.csv
# ./dataset_resized/leak/small_artificial/259.csv
# ./dataset_resized/leak/small_artificial/260.csv
# Mode 5, Iteration 600
# 0 minima > 0; 70 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 21 maxima < 0.
# Mode 9, Iteration 1000
# 1 minima > 0; 8 maxima < 0.
# Mode 9, Iteration 1200
# 0 minima > 0; 9 maxima < 0.
# Mode 9, Iteration 1400
# 0 minima > 0; 9 maxima < 0.
# Mode 9, Iteration 1600
# 0 minima > 0; 10 maxima < 0.
# Mode 9, Iteration 1800
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/261.csv
# Mode 7, Iteration 600
# 0 minima > 0; 15 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/262.csv
# ./dataset_resized/leak/small_artificial/263.csv
# ./dataset_resized/leak/small_artificial/264.csv
# Mode 8, Iteration 600
# 0 minima > 0; 11 maxima < 0.
# ./dataset_resized/leak/small_artificial/265.csv
# ./dataset_resized/leak/small_artificial/266.csv
# Mode 9, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/267.csv
# ./dataset_resized/leak/small_artificial/268.csv
# ./dataset_resized/leak/small_artificial/269.csv
# ./dataset_resized/leak/small_artificial/270.csv
# ./dataset_resized/leak/small_artificial/271.csv
# ./dataset_resized/leak/small_artificial/272.csv
# Mode 9, Iteration 600
# 1 minima > 0; 3 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/273.csv
# Mode 8, Iteration 600
# 0 minima > 0; 13 maxima < 0.
# ./dataset_resized/leak/small_artificial/274.csv
# ./dataset_resized/leak/small_artificial/275.csv
# ./dataset_resized/leak/small_artificial/276.csv
# ./dataset_resized/leak/small_artificial/277.csv
# ./dataset_resized/leak/small_artificial/278.csv
# Mode 9, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/279.csv
# Mode 9, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/280.csv
# ./dataset_resized/leak/small_artificial/281.csv
# ./dataset_resized/leak/small_artificial/282.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/283.csv
# Mode 9, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/284.csv
# Mode 6, Iteration 600
# 0 minima > 0; 41 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 16 maxima < 0.
# ./dataset_resized/leak/small_artificial/285.csv
# ./dataset_resized/leak/small_artificial/286.csv
# ./dataset_resized/leak/small_artificial/287.csv
# Mode 7, Iteration 600
# 0 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 18 maxima < 0.
# Mode 8, Iteration 1000
# 0 minima > 0; 12 maxima < 0.
# Mode 9, Iteration 1200
# 1 minima > 0; 6 maxima < 0.
# Mode 10, Iteration 1400
# 0 minima > 0; 4 maxima < 0.
# Mode 9, Iteration 600
# 1 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/288.csv
# ./dataset_resized/leak/small_artificial/289.csv
# Mode 9, Iteration 600
# 1 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/290.csv
# ./dataset_resized/leak/small_artificial/291.csv
# ./dataset_resized/leak/small_artificial/292.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 7 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/293.csv
# ./dataset_resized/leak/small_artificial/294.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/295.csv
# Mode 7, Iteration 600
# 0 minima > 0; 11 maxima < 0.
# ./dataset_resized/leak/small_artificial/296.csv
# ./dataset_resized/leak/small_artificial/297.csv
# Mode 7, Iteration 600
# 0 minima > 0; 21 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/298.csv
# ./dataset_resized/leak/small_artificial/299.csv
# ./dataset_resized/leak/small_artificial/300.csv
# ./dataset_resized/leak/small_artificial/301.csv
# Mode 7, Iteration 600
# 0 minima > 0; 24 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 13 maxima < 0.
# ./dataset_resized/leak/small_artificial/302.csv
# ./dataset_resized/leak/small_artificial/303.csv
# Mode 7, Iteration 600
# 0 minima > 0; 16 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/304.csv
# ./dataset_resized/leak/small_artificial/305.csv
# ./dataset_resized/leak/small_artificial/306.csv
# ./dataset_resized/leak/small_artificial/307.csv
# ./dataset_resized/leak/small_artificial/308.csv
# ./dataset_resized/leak/small_artificial/309.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/310.csv
# ./dataset_resized/leak/small_artificial/311.csv
# ./dataset_resized/leak/small_artificial/312.csv
# ./dataset_resized/leak/small_artificial/313.csv
# ./dataset_resized/leak/small_artificial/314.csv
# ./dataset_resized/leak/small_artificial/315.csv
# ./dataset_resized/leak/small_artificial/316.csv
# ./dataset_resized/leak/small_artificial/317.csv
# ./dataset_resized/leak/small_artificial/318.csv
# ./dataset_resized/leak/small_artificial/319.csv
# ./dataset_resized/leak/small_artificial/320.csv
# Mode 9, Iteration 600
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/321.csv
# ./dataset_resized/leak/small_artificial/322.csv
# Mode 9, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 1200
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 1400
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 1600
# 0 minima > 0; 5 maxima < 0.
# Mode 10, Iteration 1800
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/323.csv
# ./dataset_resized/leak/small_artificial/324.csv
# Mode 9, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/325.csv
# ./dataset_resized/leak/small_artificial/326.csv
# ./dataset_resized/leak/small_artificial/327.csv
# ./dataset_resized/leak/small_artificial/328.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/329.csv
# ./dataset_resized/leak/small_artificial/330.csv
# Mode 5, Iteration 600
# 0 minima > 0; 86 maxima < 0.
# Mode 5, Iteration 800
# 0 minima > 0; 86 maxima < 0.
# Mode 7, Iteration 1000
# 0 minima > 0; 27 maxima < 0.
# ./dataset_resized/leak/small_artificial/331.csv
# ./dataset_resized/leak/small_artificial/332.csv
# ./dataset_resized/leak/small_artificial/333.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/334.csv
# Mode 9, Iteration 600
# 0 minima > 0; 11 maxima < 0.
# ./dataset_resized/leak/small_artificial/335.csv
# ./dataset_resized/leak/small_artificial/336.csv
# Mode 6, Iteration 600
# 0 minima > 0; 44 maxima < 0.
# Mode 6, Iteration 800
# 1 minima > 0; 44 maxima < 0.
# Mode 9, Iteration 1000
# 1 minima > 0; 7 maxima < 0.
# Mode 10, Iteration 1200
# 1 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/337.csv
# ./dataset_resized/leak/small_artificial/338.csv
# Mode 8, Iteration 600
# 0 minima > 0; 14 maxima < 0.
# Mode 9, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/339.csv
# ./dataset_resized/leak/small_artificial/340.csv
# ./dataset_resized/leak/small_artificial/341.csv
# ./dataset_resized/leak/small_artificial/342.csv
# ./dataset_resized/leak/small_artificial/343.csv
# ./dataset_resized/leak/small_artificial/344.csv
# ./dataset_resized/leak/small_artificial/345.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/346.csv
# Mode 7, Iteration 600
# 0 minima > 0; 15 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/347.csv
# ./dataset_resized/leak/small_artificial/348.csv
# Mode 8, Iteration 600
# 1 minima > 0; 10 maxima < 0.
# Mode 8, Iteration 800
# 1 minima > 0; 10 maxima < 0.
# Mode 8, Iteration 1000
# 1 minima > 0; 10 maxima < 0.
# Mode 9, Iteration 1200
# 0 minima > 0; 5 maxima < 0.
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/349.csv
# Mode 9, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# Mode 9, Iteration 800
# 1 minima > 0; 6 maxima < 0.
# Mode 9, Iteration 1000
# 1 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/350.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/351.csv
# Mode 2, Iteration 600
# 1 minima > 0; 691 maxima < 0.
# Mode 3, Iteration 800
# 1 minima > 0; 472 maxima < 0.
# ./dataset_resized/leak/small_artificial/352.csv
# ./dataset_resized/leak/small_artificial/353.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# Mode 10, Iteration 1000
# 0 minima > 0; 3 maxima < 0.
# Mode 10, Iteration 1200
# 0 minima > 0; 3 maxima < 0.
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 1000
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 1200
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 1400
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 1600
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 1800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/354.csv
# ./dataset_resized/leak/small_artificial/355.csv
# ./dataset_resized/leak/small_artificial/356.csv
# Mode 3, Iteration 600
# 1 minima > 0; 386 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/357.csv
# ./dataset_resized/leak/small_artificial/358.csv
# ./dataset_resized/leak/small_artificial/359.csv
# ./dataset_resized/leak/small_artificial/360.csv
# ./dataset_resized/leak/small_artificial/361.csv
# Mode 6, Iteration 600
# 0 minima > 0; 34 maxima < 0.
# ./dataset_resized/leak/small_artificial/362.csv
# ./dataset_resized/leak/small_artificial/363.csv
# ./dataset_resized/leak/small_artificial/364.csv
# ./dataset_resized/leak/small_artificial/365.csv
# ./dataset_resized/leak/small_artificial/366.csv
# ./dataset_resized/leak/small_artificial/367.csv
# ./dataset_resized/leak/small_artificial/368.csv
# ./dataset_resized/leak/small_artificial/369.csv
# ./dataset_resized/leak/small_artificial/370.csv
# ./dataset_resized/leak/small_artificial/371.csv
# ./dataset_resized/leak/small_artificial/372.csv
# ./dataset_resized/leak/small_artificial/373.csv
# Mode 3, Iteration 600
# 1 minima > 0; 175 maxima < 0.
# Mode 5, Iteration 800
# 1 minima > 0; 62 maxima < 0.
# Mode 7, Iteration 1000
# 1 minima > 0; 15 maxima < 0.
# Mode 7, Iteration 1200
# 1 minima > 0; 16 maxima < 0.
# Mode 7, Iteration 1400
# 0 minima > 0; 17 maxima < 0.
# ./dataset_resized/leak/small_artificial/374.csv
# Mode 8, Iteration 600
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/375.csv
# ./dataset_resized/leak/small_artificial/376.csv
# ./dataset_resized/leak/small_artificial/377.csv
# ./dataset_resized/leak/small_artificial/378.csv
# Mode 7, Iteration 600
# 0 minima > 0; 22 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 22 maxima < 0.
# ./dataset_resized/leak/small_artificial/379.csv
# Mode 7, Iteration 600
# 0 minima > 0; 31 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 31 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 11 maxima < 0.
# Mode 11, Iteration 1200
# 1 minima > 0; 2 maxima < 0.
# ./dataset_resized/leak/small_artificial/380.csv
# ./dataset_resized/leak/small_artificial/381.csv
# ./dataset_resized/leak/small_artificial/382.csv
# Mode 7, Iteration 600
# 0 minima > 0; 18 maxima < 0.
# Mode 5, Iteration 600
# 0 minima > 0; 58 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 14 maxima < 0.
# Mode 9, Iteration 1000
# 1 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/383.csv
# Mode 9, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/384.csv
# ./dataset_resized/leak/small_artificial/385.csv
# ./dataset_resized/leak/small_artificial/386.csv
# ./dataset_resized/leak/small_artificial/387.csv
# ./dataset_resized/leak/small_artificial/388.csv
# ./dataset_resized/leak/small_artificial/389.csv
# ./dataset_resized/leak/small_artificial/390.csv
# ./dataset_resized/leak/small_artificial/391.csv
# ./dataset_resized/leak/small_artificial/392.csv
# ./dataset_resized/leak/small_artificial/393.csv
# ./dataset_resized/leak/small_artificial/394.csv
# ./dataset_resized/leak/small_artificial/395.csv
# ./dataset_resized/leak/small_artificial/396.csv
# ./dataset_resized/leak/small_artificial/397.csv
# ./dataset_resized/leak/small_artificial/398.csv
# ./dataset_resized/leak/small_artificial/399.csv
# ./dataset_resized/leak/small_artificial/400.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 1000
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 1200
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 1400
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 1600
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 1800
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/401.csv
# ./dataset_resized/leak/small_artificial/402.csv
# ./dataset_resized/leak/small_artificial/403.csv
# ./dataset_resized/leak/small_artificial/404.csv
# ./dataset_resized/leak/small_artificial/405.csv
# Mode 6, Iteration 600
# 25 minima > 0; 0 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/406.csv
# Mode 9, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/407.csv
# ./dataset_resized/leak/small_artificial/408.csv
# Mode 6, Iteration 600
# 0 minima > 0; 68 maxima < 0.
# Mode 6, Iteration 800
# 0 minima > 0; 67 maxima < 0.
# ./dataset_resized/leak/small_artificial/409.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/410.csv
# Mode 8, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# Mode 3, Iteration 600
# 1 minima > 0; 220 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 2 maxima < 0.
# ./dataset_resized/leak/small_artificial/411.csv
# Mode 3, Iteration 600
# 1 minima > 0; 137 maxima < 0.
# Mode 3, Iteration 800
# 1 minima > 0; 138 maxima < 0.
# Mode 4, Iteration 1000
# 0 minima > 0; 93 maxima < 0.
# Mode 6, Iteration 1200
# 0 minima > 0; 34 maxima < 0.
# ./dataset_resized/leak/small_artificial/412.csv
# ./dataset_resized/leak/small_artificial/413.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/414.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/415.csv
# ./dataset_resized/leak/small_artificial/416.csv
# ./dataset_resized/leak/small_artificial/417.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/418.csv
# Mode 7, Iteration 600
# 0 minima > 0; 27 maxima < 0.
# Mode 10, Iteration 800
# 1 minima > 0; 2 maxima < 0.
# ./dataset_resized/leak/small_artificial/419.csv
# ./dataset_resized/leak/small_artificial/420.csv
# ./dataset_resized/leak/small_artificial/421.csv
# ./dataset_resized/leak/small_artificial/422.csv
# Mode 9, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/423.csv
# ./dataset_resized/leak/small_artificial/424.csv
# ./dataset_resized/leak/small_artificial/425.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/426.csv
# ./dataset_resized/leak/small_artificial/427.csv
# Mode 3, Iteration 600
# 1 minima > 0; 138 maxima < 0.
# Mode 6, Iteration 800
# 0 minima > 0; 20 maxima < 0.
# Mode 8, Iteration 1000
# 2 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 1200
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/428.csv
# ./dataset_resized/leak/small_artificial/429.csv
# ./dataset_resized/leak/small_artificial/430.csv
# ./dataset_resized/leak/small_artificial/431.csv
# Mode 8, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/432.csv
# Mode 6, Iteration 600
# 0 minima > 0; 59 maxima < 0.
# ./dataset_resized/leak/small_artificial/433.csv
# ./dataset_resized/leak/small_artificial/434.csv
# ./dataset_resized/leak/small_artificial/435.csv
# Mode 8, Iteration 600
# 0 minima > 0; 11 maxima < 0.
# ./dataset_resized/leak/small_artificial/436.csv
# ./dataset_resized/leak/small_artificial/437.csv
# ./dataset_resized/leak/small_artificial/438.csv
# ./dataset_resized/leak/small_artificial/439.csv
# Mode 9, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/440.csv
# ./dataset_resized/leak/small_artificial/441.csv
# Mode 6, Iteration 600
# 0 minima > 0; 59 maxima < 0.
# ./dataset_resized/leak/small_artificial/442.csv
# ./dataset_resized/leak/small_artificial/443.csv
# ./dataset_resized/leak/small_artificial/444.csv
# ./dataset_resized/leak/small_artificial/445.csv
# Mode 7, Iteration 600
# 0 minima > 0; 34 maxima < 0.
# Mode 5, Iteration 600
# 0 minima > 0; 50 maxima < 0.
# Mode 5, Iteration 800
# 0 minima > 0; 50 maxima < 0.
# ./dataset_resized/leak/small_artificial/446.csv
# ./dataset_resized/leak/small_artificial/447.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/448.csv
# ./dataset_resized/leak/small_artificial/449.csv
# ./dataset_resized/leak/small_artificial/450.csv
# ./dataset_resized/leak/small_artificial/451.csv
# ./dataset_resized/leak/small_artificial/452.csv
# ./dataset_resized/leak/small_artificial/453.csv
# Mode 9, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/454.csv
# Mode 7, Iteration 600
# 0 minima > 0; 35 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/455.csv
# Mode 9, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/456.csv
# ./dataset_resized/leak/small_artificial/457.csv
# Mode 5, Iteration 600
# 0 minima > 0; 30 maxima < 0.
# Mode 6, Iteration 800
# 0 minima > 0; 23 maxima < 0.
# Mode 7, Iteration 1000
# 0 minima > 0; 14 maxima < 0.
# ./dataset_resized/leak/small_artificial/458.csv
# ./dataset_resized/leak/small_artificial/459.csv
# Mode 8, Iteration 600
# 0 minima > 0; 13 maxima < 0.
# ./dataset_resized/leak/small_artificial/460.csv
# ./dataset_resized/leak/small_artificial/461.csv
# Mode 9, Iteration 600
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/462.csv
# ./dataset_resized/leak/small_artificial/463.csv
# Mode 10, Iteration 600
# 0 minima > 0; 2 maxima < 0.
# Mode 3, Iteration 600
# 0 minima > 0; 494 maxima < 0.
# Mode 7, Iteration 800
# 1 minima > 0; 25 maxima < 0.
# ./dataset_resized/leak/small_artificial/464.csv
# Mode 9, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/465.csv
# ./dataset_resized/leak/small_artificial/466.csv
# ./dataset_resized/leak/small_artificial/467.csv
# Mode 9, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/468.csv
# ./dataset_resized/leak/small_artificial/469.csv
# ./dataset_resized/leak/small_artificial/470.csv
# ./dataset_resized/leak/small_artificial/471.csv
# ./dataset_resized/leak/small_artificial/472.csv
# ./dataset_resized/leak/small_artificial/473.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 9, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/474.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/475.csv
# ./dataset_resized/leak/small_artificial/476.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/477.csv
# Mode 9, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/478.csv
# Mode 7, Iteration 600
# 0 minima > 0; 19 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 19 maxima < 0.
# Mode 7, Iteration 1000
# 0 minima > 0; 19 maxima < 0.
# Mode 9, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/479.csv
# ./dataset_resized/leak/small_artificial/480.csv
# ./dataset_resized/leak/small_artificial/481.csv
# ./dataset_resized/leak/small_artificial/482.csv
# ./dataset_resized/leak/small_artificial/483.csv
# ./dataset_resized/leak/small_artificial/484.csv
# ./dataset_resized/leak/small_artificial/485.csv
# ./dataset_resized/leak/small_artificial/486.csv
# ./dataset_resized/leak/small_artificial/487.csv
# ./dataset_resized/leak/small_artificial/488.csv
# ./dataset_resized/leak/small_artificial/489.csv
# ./dataset_resized/leak/small_artificial/490.csv
# Mode 8, Iteration 600
# 0 minima > 0; 11 maxima < 0.
# ./dataset_resized/leak/small_artificial/491.csv
# ./dataset_resized/leak/small_artificial/492.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/493.csv
# Mode 7, Iteration 600
# 0 minima > 0; 38 maxima < 0.
# ./dataset_resized/leak/small_artificial/494.csv
# ./dataset_resized/leak/small_artificial/495.csv
# ./dataset_resized/leak/small_artificial/496.csv
# ./dataset_resized/leak/small_artificial/497.csv
# ./dataset_resized/leak/small_artificial/498.csv
# Mode 7, Iteration 600
# 1 minima > 0; 12 maxima < 0.
# Mode 9, Iteration 800
# 3 minima > 0; 0 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/499.csv
# ./dataset_resized/leak/small_artificial/500.csv
# ./dataset_resized/leak/small_artificial/501.csv
# ./dataset_resized/leak/small_artificial/502.csv
# ./dataset_resized/leak/small_artificial/503.csv
# Mode 8, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/504.csv
# ./dataset_resized/leak/small_artificial/505.csv
# ./dataset_resized/leak/small_artificial/506.csv
# Mode 9, Iteration 600
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/507.csv
# ./dataset_resized/leak/small_artificial/508.csv
# Mode 6, Iteration 600
# 0 minima > 0; 40 maxima < 0.
# Mode 6, Iteration 800
# 0 minima > 0; 40 maxima < 0.
# Mode 10, Iteration 1000
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/509.csv
# ./dataset_resized/leak/small_artificial/510.csv
# ./dataset_resized/leak/small_artificial/511.csv
# ./dataset_resized/leak/small_artificial/512.csv
# ./dataset_resized/leak/small_artificial/513.csv
# Mode 9, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/514.csv
# Mode 6, Iteration 600
# 0 minima > 0; 35 maxima < 0.
# ./dataset_resized/leak/small_artificial/515.csv
# Mode 7, Iteration 600
# 0 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 1000
# 0 minima > 0; 17 maxima < 0.
# Mode 7, Iteration 1200
# 0 minima > 0; 17 maxima < 0.
# Mode 9, Iteration 1400
# 1 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/516.csv
# ./dataset_resized/leak/small_artificial/517.csv
# Mode 9, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/518.csv
# ./dataset_resized/leak/small_artificial/519.csv
# Mode 5, Iteration 600
# 0 minima > 0; 143 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 35 maxima < 0.
# Mode 10, Iteration 1000
# 1 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/520.csv
# Mode 9, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/521.csv
# Mode 9, Iteration 600
# 0 minima > 0; 10 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 10 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/522.csv
# ./dataset_resized/leak/small_artificial/523.csv
# ./dataset_resized/leak/small_artificial/524.csv
# ./dataset_resized/leak/small_artificial/525.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 1000
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 1200
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/526.csv
# Mode 3, Iteration 600
# 1 minima > 0; 163 maxima < 0.
# Mode 4, Iteration 800
# 0 minima > 0; 117 maxima < 0.
# ./dataset_resized/leak/small_artificial/527.csv
# Mode 7, Iteration 600
# 1 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/528.csv
# ./dataset_resized/leak/small_artificial/529.csv
# Mode 9, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/530.csv
# ./dataset_resized/leak/small_artificial/531.csv
# ./dataset_resized/leak/small_artificial/532.csv
# ./dataset_resized/leak/small_artificial/533.csv
# ./dataset_resized/leak/small_artificial/534.csv
# Mode 8, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 6 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/535.csv
# ./dataset_resized/leak/small_artificial/536.csv
# ./dataset_resized/leak/small_artificial/537.csv
# Mode 8, Iteration 600
# 0 minima > 0; 11 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/538.csv
# Mode 9, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/539.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# Mode 9, Iteration 1000
# 0 minima > 0; 4 maxima < 0.
# Mode 9, Iteration 1200
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/540.csv
# Mode 6, Iteration 600
# 0 minima > 0; 26 maxima < 0.
# ./dataset_resized/leak/small_artificial/541.csv
# ./dataset_resized/leak/small_artificial/542.csv
# ./dataset_resized/leak/small_artificial/543.csv
# Mode 4, Iteration 600
# 1 minima > 0; 202 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/544.csv
# ./dataset_resized/leak/small_artificial/545.csv
# Mode 8, Iteration 600
# 0 minima > 0; 12 maxima < 0.
# ./dataset_resized/leak/small_artificial/546.csv
# ./dataset_resized/leak/small_artificial/547.csv
# ./dataset_resized/leak/small_artificial/548.csv
# ./dataset_resized/leak/small_artificial/549.csv
# Mode 8, Iteration 600
# 0 minima > 0; 17 maxima < 0.
# ./dataset_resized/leak/small_artificial/550.csv
# Mode 5, Iteration 600
# 0 minima > 0; 70 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 24 maxima < 0.
# ./dataset_resized/leak/small_artificial/551.csv
# ./dataset_resized/leak/small_artificial/552.csv
# Mode 6, Iteration 600
# 0 minima > 0; 52 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 35 maxima < 0.
# ./dataset_resized/leak/small_artificial/553.csv
# ...
# ./dataset_resized/leak/small_artificial/1898.csv
# ./dataset_resized/leak/small_artificial/1899.csv
# ./dataset_resized/leak/small_artificial/1900.csv
# ./dataset_resized/leak/small_artificial/1901.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/1902.csv
# ./dataset_resized/leak/small_artificial/1903.csv
# ./dataset_resized/leak/small_artificial/1904.csv
# ./dataset_resized/leak/small_artificial/1905.csv
# ./dataset_resized/leak/small_artificial/1906.csv
# ./dataset_resized/leak/small_artificial/1907.csv
# ./dataset_resized/leak/small_artificial/1908.csv
# ./dataset_resized/leak/small_artificial/1909.csv
# ./dataset_resized/leak/small_artificial/1910.csv
# ./dataset_resized/leak/small_artificial/1911.csv
# ./dataset_resized/leak/small_artificial/1912.csv
# ./dataset_resized/leak/small_artificial/1913.csv
# Mode 8, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/1914.csv
# ./dataset_resized/leak/small_artificial/1915.csv
# ./dataset_resized/leak/small_artificial/1916.csv
# ./dataset_resized/leak/small_artificial/1917.csv
# ./dataset_resized/leak/small_artificial/1918.csv
# Mode 8, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/1919.csv
# ./dataset_resized/leak/small_artificial/1920.csv
# ./dataset_resized/leak/small_artificial/1921.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/1922.csv
# ./dataset_resized/leak/small_artificial/1923.csv
# ./dataset_resized/leak/small_artificial/1924.csv
# ./dataset_resized/leak/small_artificial/1925.csv
# ./dataset_resized/leak/small_artificial/1926.csv
# ./dataset_resized/leak/small_artificial/1927.csv
# ./dataset_resized/leak/small_artificial/1928.csv
# Mode 9, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/1929.csv
# ./dataset_resized/leak/small_artificial/1930.csv
# ./dataset_resized/leak/small_artificial/1931.csv
# ./dataset_resized/leak/small_artificial/1932.csv
# Mode 7, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# Mode 7, Iteration 800
# 0 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/1933.csv
# ./dataset_resized/leak/small_artificial/1934.csv
# ./dataset_resized/leak/small_artificial/1935.csv
# ./dataset_resized/leak/small_artificial/1936.csv
# ./dataset_resized/leak/small_artificial/1937.csv
# ./dataset_resized/leak/small_artificial/1938.csv
# ./dataset_resized/leak/small_artificial/1939.csv
# ./dataset_resized/leak/small_artificial/1940.csv
# ./dataset_resized/leak/small_artificial/1941.csv
# ./dataset_resized/leak/small_artificial/1942.csv
# ./dataset_resized/leak/small_artificial/1943.csv
# ./dataset_resized/leak/small_artificial/1944.csv
# ./dataset_resized/leak/small_artificial/1945.csv
# ./dataset_resized/leak/small_artificial/1946.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/1947.csv
# ./dataset_resized/leak/small_artificial/1948.csv
# ./dataset_resized/leak/small_artificial/1949.csv
# ./dataset_resized/leak/small_artificial/1950.csv
# ./dataset_resized/leak/small_artificial/1951.csv
# ./dataset_resized/leak/small_artificial/1952.csv
# ./dataset_resized/leak/small_artificial/1953.csv
# ./dataset_resized/leak/small_artificial/1954.csv
# ./dataset_resized/leak/small_artificial/1955.csv
# ./dataset_resized/leak/small_artificial/1956.csv
# ./dataset_resized/leak/small_artificial/1957.csv
# ./dataset_resized/leak/small_artificial/1958.csv
# Mode 10, Iteration 600
# 1 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/1959.csv
# ./dataset_resized/leak/small_artificial/1960.csv
# Mode 8, Iteration 600
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/1961.csv
# Mode 9, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# Mode 9, Iteration 800
# 1 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/1962.csv
# ./dataset_resized/leak/small_artificial/1963.csv
# ./dataset_resized/leak/small_artificial/1964.csv
# Mode 8, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# Mode 8, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/1965.csv
# ./dataset_resized/leak/small_artificial/1966.csv
# ./dataset_resized/leak/small_artificial/1967.csv
# ./dataset_resized/leak/small_artificial/1968.csv
# ./dataset_resized/leak/small_artificial/1969.csv
# ./dataset_resized/leak/small_artificial/1970.csv
# ./dataset_resized/leak/small_artificial/1971.csv
# ./dataset_resized/leak/small_artificial/1972.csv
# Mode 10, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/1973.csv
# ./dataset_resized/leak/small_artificial/1974.csv
# ./dataset_resized/leak/small_artificial/1975.csv
# ./dataset_resized/leak/small_artificial/1976.csv
# ./dataset_resized/leak/small_artificial/1977.csv
# ./dataset_resized/leak/small_artificial/1978.csv
# ./dataset_resized/leak/small_artificial/1979.csv
# ./dataset_resized/leak/small_artificial/1980.csv
# ./dataset_resized/leak/small_artificial/1981.csv
# Mode 9, Iteration 600
# 1 minima > 0; 6 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# Mode 10, Iteration 1000
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/1982.csv
# ./dataset_resized/leak/small_artificial/1983.csv
# ./dataset_resized/leak/small_artificial/1984.csv
# ./dataset_resized/leak/small_artificial/1985.csv
# ./dataset_resized/leak/small_artificial/1986.csv
# ./dataset_resized/leak/small_artificial/1987.csv
# ./dataset_resized/leak/small_artificial/1988.csv
# ./dataset_resized/leak/small_artificial/1989.csv
# ./dataset_resized/leak/small_artificial/1990.csv
# ./dataset_resized/leak/small_artificial/1991.csv
# Mode 9, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/1992.csv
# ./dataset_resized/leak/small_artificial/1993.csv
# ./dataset_resized/leak/small_artificial/1994.csv
# ./dataset_resized/leak/small_artificial/1995.csv
# ./dataset_resized/leak/small_artificial/1996.csv
# ./dataset_resized/leak/small_artificial/1997.csv
# ./dataset_resized/leak/small_artificial/1998.csv
# ./dataset_resized/leak/small_artificial/1999.csv
# ./dataset_resized/leak/small_artificial/2000.csv
# ./dataset_resized/leak/small_artificial/2001.csv
# ./dataset_resized/leak/small_artificial/2002.csv
# ./dataset_resized/leak/small_artificial/2003.csv
# Mode 8, Iteration 600
# 1 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/2004.csv
# Mode 7, Iteration 600
# 0 minima > 0; 14 maxima < 0.
# ./dataset_resized/leak/small_artificial/2005.csv
# ./dataset_resized/leak/small_artificial/2006.csv
# ./dataset_resized/leak/small_artificial/2007.csv
# ./dataset_resized/leak/small_artificial/2008.csv
# ./dataset_resized/leak/small_artificial/2009.csv
# ./dataset_resized/leak/small_artificial/2010.csv
# ./dataset_resized/leak/small_artificial/2011.csv
# ./dataset_resized/leak/small_artificial/2012.csv
# ./dataset_resized/leak/small_artificial/2013.csv
# ./dataset_resized/leak/small_artificial/2014.csv
# ./dataset_resized/leak/small_artificial/2015.csv
# ./dataset_resized/leak/small_artificial/2016.csv
# ./dataset_resized/leak/small_artificial/2017.csv
# ./dataset_resized/leak/small_artificial/2018.csv
# Mode 9, Iteration 600
# 3 minima > 0; 0 maxima < 0.
# ./dataset_resized/leak/small_artificial/2019.csv
# ./dataset_resized/leak/small_artificial/2020.csv
# ./dataset_resized/leak/small_artificial/2021.csv
# ./dataset_resized/leak/small_artificial/2022.csv
# Mode 8, Iteration 600
# 0 minima > 0; 12 maxima < 0.
# ./dataset_resized/leak/small_artificial/2023.csv
# ./dataset_resized/leak/small_artificial/2024.csv
# ./dataset_resized/leak/small_artificial/2025.csv
# ./dataset_resized/leak/small_artificial/2026.csv
# ./dataset_resized/leak/small_artificial/2027.csv
# ./dataset_resized/leak/small_artificial/2028.csv
# ./dataset_resized/leak/small_artificial/2029.csv
# ./dataset_resized/leak/small_artificial/2030.csv
# ./dataset_resized/leak/small_artificial/2031.csv
# Mode 8, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/2032.csv
# Mode 7, Iteration 600
# 0 minima > 0; 14 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/2033.csv
# Mode 9, Iteration 600
# 0 minima > 0; 2 maxima < 0.
# ./dataset_resized/leak/small_artificial/2034.csv
# ./dataset_resized/leak/small_artificial/2035.csv
# ./dataset_resized/leak/small_artificial/2036.csv
# ./dataset_resized/leak/small_artificial/2037.csv
# ./dataset_resized/leak/small_artificial/2038.csv
# ./dataset_resized/leak/small_artificial/2039.csv
# ./dataset_resized/leak/small_artificial/2040.csv
# Mode 9, Iteration 600
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/2041.csv
# ./dataset_resized/leak/small_artificial/2042.csv
# ./dataset_resized/leak/small_artificial/2043.csv
# ./dataset_resized/leak/small_artificial/2044.csv
# ./dataset_resized/leak/small_artificial/2045.csv
# ./dataset_resized/leak/small_artificial/2046.csv
# ./dataset_resized/leak/small_artificial/2047.csv
# ./dataset_resized/leak/small_artificial/2048.csv
# ./dataset_resized/leak/small_artificial/2049.csv
# ./dataset_resized/leak/small_artificial/2050.csv
# Mode 9, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/2051.csv
# ./dataset_resized/leak/small_artificial/2052.csv
# ./dataset_resized/leak/small_artificial/2053.csv
# ./dataset_resized/leak/small_artificial/2054.csv
# ./dataset_resized/leak/small_artificial/2055.csv
# ./dataset_resized/leak/small_artificial/2056.csv
# ./dataset_resized/leak/small_artificial/2057.csv
# ./dataset_resized/leak/small_artificial/2058.csv
# ./dataset_resized/leak/small_artificial/2059.csv
# ./dataset_resized/leak/small_artificial/2060.csv
# ./dataset_resized/leak/small_artificial/2061.csv
# Mode 9, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/2062.csv
# ./dataset_resized/leak/small_artificial/2063.csv
# ./dataset_resized/leak/small_artificial/2064.csv
# ./dataset_resized/leak/small_artificial/2065.csv
# ./dataset_resized/leak/small_artificial/2066.csv
# ./dataset_resized/leak/small_artificial/2067.csv
# ./dataset_resized/leak/small_artificial/2068.csv
# ./dataset_resized/leak/small_artificial/2069.csv
# Mode 8, Iteration 600
# 0 minima > 0; 12 maxima < 0.
# ./dataset_resized/leak/small_artificial/2070.csv
# ./dataset_resized/leak/small_artificial/2071.csv
# ./dataset_resized/leak/small_artificial/2072.csv
# ./dataset_resized/leak/small_artificial/2073.csv
# ./dataset_resized/leak/small_artificial/2074.csv
# ./dataset_resized/leak/small_artificial/2075.csv
# ./dataset_resized/leak/small_artificial/2076.csv
# ./dataset_resized/leak/small_artificial/2077.csv
# ./dataset_resized/leak/small_artificial/2078.csv
# ./dataset_resized/leak/small_artificial/2079.csv
# ./dataset_resized/leak/small_artificial/2080.csv
# ./dataset_resized/leak/small_artificial/2081.csv
# ./dataset_resized/leak/small_artificial/2082.csv
# ./dataset_resized/leak/small_artificial/2083.csv
# ./dataset_resized/leak/small_artificial/2084.csv
# ./dataset_resized/leak/small_artificial/2085.csv
# ./dataset_resized/leak/small_artificial/2086.csv
# ./dataset_resized/leak/small_artificial/2087.csv
# ./dataset_resized/leak/small_artificial/2088.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# ./dataset_resized/leak/small_artificial/2089.csv
# ./dataset_resized/leak/small_artificial/2090.csv
# ./dataset_resized/leak/small_artificial/2091.csv
# ./dataset_resized/leak/small_artificial/2092.csv
# ./dataset_resized/leak/small_artificial/2093.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 9 maxima < 0.
# Mode 10, Iteration 1000
# 0 minima > 0; 3 maxima < 0.
# Mode 7, Iteration 600
# 0 minima > 0; 25 maxima < 0.
# Mode 9, Iteration 800
# 0 minima > 0; 5 maxima < 0.
# Mode 10, Iteration 1000
# 0 minima > 0; 4 maxima < 0.
# Mode 10, Iteration 1200
# 0 minima > 0; 5 maxima < 0.
# Mode 10, Iteration 1400
# 1 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/2094.csv
# ./dataset_resized/leak/small_artificial/2095.csv
# ./dataset_resized/leak/small_artificial/2096.csv
# ./dataset_resized/leak/small_artificial/2097.csv
# ./dataset_resized/leak/small_artificial/2098.csv
# ./dataset_resized/leak/small_artificial/2099.csv
# Mode 8, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/2100.csv
# Mode 8, Iteration 600
# 0 minima > 0; 8 maxima < 0.
# ./dataset_resized/leak/small_artificial/2101.csv
# ./dataset_resized/leak/small_artificial/2102.csv
# Mode 8, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/2103.csv
# ./dataset_resized/leak/small_artificial/2104.csv
# ./dataset_resized/leak/small_artificial/2105.csv
# ./dataset_resized/leak/small_artificial/2106.csv
# ./dataset_resized/leak/small_artificial/2107.csv
# ./dataset_resized/leak/small_artificial/2108.csv
# ./dataset_resized/leak/small_artificial/2109.csv
# ./dataset_resized/leak/small_artificial/2110.csv
# ./dataset_resized/leak/small_artificial/2111.csv
# Mode 9, Iteration 600
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/2112.csv
# ./dataset_resized/leak/small_artificial/2113.csv
# ./dataset_resized/leak/small_artificial/2114.csv
# ./dataset_resized/leak/small_artificial/2115.csv
# ./dataset_resized/leak/small_artificial/2116.csv
# Mode 8, Iteration 600
# 0 minima > 0; 7 maxima < 0.
# ./dataset_resized/leak/small_artificial/2117.csv
# ./dataset_resized/leak/small_artificial/2118.csv
# Mode 7, Iteration 600
# 0 minima > 0; 21 maxima < 0.
# Mode 10, Iteration 800
# 0 minima > 0; 3 maxima < 0.
# ./dataset_resized/leak/small_artificial/2119.csv
# Mode 8, Iteration 600
# 1 minima > 0; 4 maxima < 0.
# Mode 8, Iteration 800
# 0 minima > 0; 4 maxima < 0.
# Mode 8, Iteration 1000
# 1 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/2120.csv
# ./dataset_resized/leak/small_artificial/2121.csv
# Mode 10, Iteration 600
# 0 minima > 0; 4 maxima < 0.
# ./dataset_resized/leak/small_artificial/2122.csv
# ./dataset_resized/leak/small_artificial/2123.csv
# ./dataset_resized/leak/small_artificial/2124.csv
# ./dataset_resized/leak/small_artificial/2125.csv
# ./dataset_resized/leak/small_artificial/2126.csv
# Mode 8, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# ./dataset_resized/leak/small_artificial/2127.csv
# ./dataset_resized/leak/small_artificial/2128.csv
# Mode 9, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/2129.csv
# ./dataset_resized/leak/small_artificial/2130.csv
# ./dataset_resized/leak/small_artificial/2131.csv
# Mode 7, Iteration 600
# 0 minima > 0; 10 maxima < 0.
# ./dataset_resized/leak/small_artificial/2132.csv
# ./dataset_resized/leak/small_artificial/2133.csv
# ./dataset_resized/leak/small_artificial/2134.csv
# ./dataset_resized/leak/small_artificial/2135.csv
# ./dataset_resized/leak/small_artificial/2136.csv
# ./dataset_resized/leak/small_artificial/2137.csv
# ./dataset_resized/leak/small_artificial/2138.csv
# ./dataset_resized/leak/small_artificial/2139.csv
# ./dataset_resized/leak/small_artificial/2140.csv
# ./dataset_resized/leak/small_artificial/2141.csv
# ./dataset_resized/leak/small_artificial/2142.csv
# Mode 8, Iteration 600
# 0 minima > 0; 6 maxima < 0.
# ./dataset_resized/leak/small_artificial/2143.csv
# ./dataset_resized/leak/small_artificial/2144.csv
# ./dataset_resized/leak/small_artificial/2145.csv
# ./dataset_resized/leak/small_artificial/2146.csv
# ./dataset_resized/leak/small_artificial/2147.csv
# ./dataset_resized/leak/small_artificial/2148.csv
# ./dataset_resized/leak/small_artificial/2149.csv
# ./dataset_resized/leak/small_artificial/2150.csv
# ./dataset_resized/leak/small_artificial/2151.csv
# ./dataset_resized/leak/small_artificial/2152.csv
# ./dataset_resized/leak/small_artificial/2153.csv
# ./dataset_resized/leak/small_artificial/2154.csv
# ./dataset_resized/leak/small_artificial/2155.csv
# ./dataset_resized/leak/small_artificial/2156.csv
# ./dataset_resized/leak/small_artificial/2157.csv
# ./dataset_resized/leak/small_artificial/2158.csv
# ./dataset_resized/leak/small_artificial/2159.csv
# ./dataset_resized/leak/small_artificial/2160.csv
# ./dataset_resized/leak/small_artificial/2161.csv

# %%
#save features into the .csv file
df.to_csv(dataset_filename, sep=',')
